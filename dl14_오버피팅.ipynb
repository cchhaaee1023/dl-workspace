# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms.v2 as transforms
import matplotlib.pyplot as plt

# 데이터 변환 및 로드
transform = transforms.Compose([
    transforms.ToImage(),
    transforms.ToDtype(torch.float32, scale=True)
])

# 학습 데이터셋 (일부만 사용하여 오버피팅 유도)
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
subset_indices = torch.arange(0, 2000)  # 학습 데이터 2000개만 사용
train_subset = torch.utils.data.Subset(train_dataset, subset_indices)
train_loader = torch.utils.data.DataLoader(train_subset, batch_size=64, shuffle=True)

# 테스트 데이터셋
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# 100%|██████████| 9.91M/9.91M [00:03<00:00, 2.56MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 149kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.27MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 7.03MB/s]

# %%
class OverfittingNet(nn.Module):
    def __init__(self):
        super(OverfittingNet, self).__init__()
        self.flatten = nn.Flatten()
        self.layer1 = nn.Linear(1*28*28, 2048)
        self.relu1 = nn.ReLU()
        self.layer2 = nn.Linear(2048, 1024)
        self.relu2 = nn.ReLU()
        self.layer3 = nn.Linear(1024, 512)
        self.relu3 = nn.ReLU()
        self.layer4 = nn.Linear(512, 10)

    def forward(self, x):
        x = self.flatten(x)
        x = self.relu1(self.layer1(x))
        x = self.relu2(self.layer2(x))
        x = self.relu3(self.layer3(x))
        x = self.layer4(x)
        return x

# 모델, 손실 함수, 옵티마이저 정의
model = OverfittingNet()

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
# 학습 함수
def train(model, loader, optimizer, criterion):
    model.train()
    running_loss = 0.0
    for inputs, targets in loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    return running_loss / len(loader)

# 평가 함수
def evaluate(model, loader, criterion):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in loader:
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    accuracy = 100 * correct / total
    return running_loss / len(loader), accuracy

# %%
# 학습 및 평가 기록을 저장할 리스트
train_losses = []
test_losses = []
test_accuracies = []

num_epochs = 100
for epoch in range(num_epochs):
    train_loss = train(model, train_loader, optimizer, criterion)
    test_loss, test_accuracy = evaluate(model, test_loader, criterion)

    train_losses.append(train_loss)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)

    print(f'Epoch [{epoch+1}/{num_epochs}] - Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Accuracy: {test_accuracy:.2f}%')

# 손실 곡선 시각화
plt.figure(figsize=(10,5))
plt.title('Loss')
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 정확도 곡선 시각화
plt.figure(figsize=(10,5))
plt.title('Accuracy')
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()
# Out:
# Epoch [1/100] - Train Loss: 1.6061, Test Loss: 0.8533, Accuracy: 73.29%
# Epoch [2/100] - Train Loss: 0.4440, Test Loss: 0.4970, Accuracy: 85.81%
# Epoch [3/100] - Train Loss: 0.3031, Test Loss: 0.5002, Accuracy: 87.64%
# Epoch [4/100] - Train Loss: 0.2240, Test Loss: 0.5659, Accuracy: 86.07%
# Epoch [5/100] - Train Loss: 0.1543, Test Loss: 0.5931, Accuracy: 86.62%
# Epoch [6/100] - Train Loss: 0.1905, Test Loss: 0.6484, Accuracy: 86.92%
# Epoch [7/100] - Train Loss: 0.2071, Test Loss: 0.5942, Accuracy: 88.77%
# Epoch [8/100] - Train Loss: 0.1973, Test Loss: 0.6682, Accuracy: 87.40%
# Epoch [9/100] - Train Loss: 0.1344, Test Loss: 0.7812, Accuracy: 88.76%
# Epoch [10/100] - Train Loss: 0.1424, Test Loss: 0.6908, Accuracy: 88.87%
# Epoch [11/100] - Train Loss: 0.1629, Test Loss: 0.6168, Accuracy: 88.83%
# Epoch [12/100] - Train Loss: 0.1447, Test Loss: 1.0104, Accuracy: 87.42%
# Epoch [13/100] - Train Loss: 0.1685, Test Loss: 0.5902, Accuracy: 90.36%
# Epoch [14/100] - Train Loss: 0.0805, Test Loss: 0.6340, Accuracy: 89.68%
# Epoch [15/100] - Train Loss: 0.1343, Test Loss: 0.7773, Accuracy: 89.10%
# Epoch [16/100] - Train Loss: 0.1761, Test Loss: 0.6527, Accuracy: 87.83%
# Epoch [17/100] - Train Loss: 0.1283, Test Loss: 0.7795, Accuracy: 90.14%
# Epoch [18/100] - Train Loss: 0.0911, Test Loss: 0.9424, Accuracy: 88.20%
# Epoch [19/100] - Train Loss: 0.0843, Test Loss: 0.9290, Accuracy: 89.19%
# Epoch [20/100] - Train Loss: 0.1027, Test Loss: 1.0272, Accuracy: 88.42%
# Epoch [21/100] - Train Loss: 0.1407, Test Loss: 1.0934, Accuracy: 86.07%
# Epoch [22/100] - Train Loss: 0.1512, Test Loss: 0.8937, Accuracy: 89.31%
# Epoch [23/100] - Train Loss: 0.1505, Test Loss: 0.8574, Accuracy: 86.89%
# Epoch [24/100] - Train Loss: 0.1121, Test Loss: 1.1875, Accuracy: 89.14%
# Epoch [25/100] - Train Loss: 0.1830, Test Loss: 1.2508, Accuracy: 87.05%
# Epoch [26/100] - Train Loss: 0.2118, Test Loss: 1.1659, Accuracy: 86.47%
# Epoch [27/100] - Train Loss: 0.1846, Test Loss: 0.8401, Accuracy: 89.88%
# Epoch [28/100] - Train Loss: 0.1103, Test Loss: 1.1027, Accuracy: 89.46%
# Epoch [29/100] - Train Loss: 0.0738, Test Loss: 1.5391, Accuracy: 88.70%
# Epoch [30/100] - Train Loss: 0.0379, Test Loss: 1.4248, Accuracy: 90.66%
# Epoch [31/100] - Train Loss: 0.0531, Test Loss: 1.4418, Accuracy: 88.49%
# Epoch [32/100] - Train Loss: 0.0302, Test Loss: 1.2254, Accuracy: 90.53%
# Epoch [33/100] - Train Loss: 0.0063, Test Loss: 1.4340, Accuracy: 90.61%
# Epoch [34/100] - Train Loss: 0.0675, Test Loss: 1.2754, Accuracy: 90.40%
# Epoch [35/100] - Train Loss: 0.0232, Test Loss: 1.0345, Accuracy: 90.71%
# Epoch [36/100] - Train Loss: 0.0033, Test Loss: 1.0805, Accuracy: 91.01%
# Epoch [37/100] - Train Loss: 0.0021, Test Loss: 1.2492, Accuracy: 90.56%
# Epoch [38/100] - Train Loss: 0.0115, Test Loss: 1.1970, Accuracy: 90.32%
# Epoch [39/100] - Train Loss: 0.0632, Test Loss: 1.0811, Accuracy: 89.58%
# Epoch [40/100] - Train Loss: 0.1537, Test Loss: 2.5877, Accuracy: 86.47%
# Epoch [41/100] - Train Loss: 0.4263, Test Loss: 1.2453, Accuracy: 87.47%
# Epoch [42/100] - Train Loss: 0.2562, Test Loss: 0.9064, Accuracy: 88.57%
# Epoch [43/100] - Train Loss: 0.2743, Test Loss: 1.0013, Accuracy: 87.02%
# Epoch [44/100] - Train Loss: 0.3097, Test Loss: 1.4827, Accuracy: 83.66%
# Epoch [45/100] - Train Loss: 0.1516, Test Loss: 1.1378, Accuracy: 87.03%
# Epoch [46/100] - Train Loss: 0.0885, Test Loss: 1.0847, Accuracy: 88.86%
# Epoch [47/100] - Train Loss: 0.0758, Test Loss: 1.1525, Accuracy: 89.72%
# Epoch [48/100] - Train Loss: 0.1231, Test Loss: 0.9124, Accuracy: 89.75%
# Epoch [49/100] - Train Loss: 0.0973, Test Loss: 1.2223, Accuracy: 89.32%
# Epoch [50/100] - Train Loss: 0.0634, Test Loss: 1.6265, Accuracy: 88.25%
# Epoch [51/100] - Train Loss: 0.0395, Test Loss: 1.4422, Accuracy: 90.44%
# Epoch [52/100] - Train Loss: 0.0177, Test Loss: 2.0130, Accuracy: 90.13%
# Epoch [53/100] - Train Loss: 0.1114, Test Loss: 1.7663, Accuracy: 88.42%
# Epoch [54/100] - Train Loss: 0.1483, Test Loss: 1.2560, Accuracy: 88.60%
# Epoch [55/100] - Train Loss: 0.0757, Test Loss: 1.5412, Accuracy: 90.08%
# Epoch [56/100] - Train Loss: 0.0291, Test Loss: 1.7130, Accuracy: 90.05%
# Epoch [57/100] - Train Loss: 0.0213, Test Loss: 1.8130, Accuracy: 90.57%
# Epoch [58/100] - Train Loss: 0.0648, Test Loss: 2.0552, Accuracy: 89.47%
# Epoch [59/100] - Train Loss: 0.0478, Test Loss: 1.8591, Accuracy: 90.31%
# Epoch [60/100] - Train Loss: 0.1658, Test Loss: 1.5108, Accuracy: 89.28%
# Epoch [61/100] - Train Loss: 0.0942, Test Loss: 2.3916, Accuracy: 89.50%
# Epoch [62/100] - Train Loss: 0.0904, Test Loss: 2.1869, Accuracy: 89.57%
# Epoch [63/100] - Train Loss: 0.2128, Test Loss: 1.0301, Accuracy: 86.79%
# Epoch [64/100] - Train Loss: 0.0639, Test Loss: 1.4729, Accuracy: 90.02%
# Epoch [65/100] - Train Loss: 0.0096, Test Loss: 1.5051, Accuracy: 90.71%
# Epoch [66/100] - Train Loss: 0.0118, Test Loss: 1.5276, Accuracy: 90.56%
# Epoch [67/100] - Train Loss: 0.0102, Test Loss: 1.5590, Accuracy: 90.71%
# Epoch [68/100] - Train Loss: 0.0078, Test Loss: 1.5698, Accuracy: 90.70%
# Epoch [69/100] - Train Loss: 0.0093, Test Loss: 1.5605, Accuracy: 90.81%
# Epoch [70/100] - Train Loss: 0.0075, Test Loss: 1.5540, Accuracy: 90.78%
# Epoch [71/100] - Train Loss: 0.0062, Test Loss: 1.5485, Accuracy: 90.75%
# Epoch [72/100] - Train Loss: 0.0064, Test Loss: 1.5461, Accuracy: 90.82%
# Epoch [73/100] - Train Loss: 0.0062, Test Loss: 1.5715, Accuracy: 90.83%
# Epoch [74/100] - Train Loss: 0.0058, Test Loss: 1.5775, Accuracy: 90.81%
# Epoch [75/100] - Train Loss: 0.0056, Test Loss: 1.5900, Accuracy: 90.76%
# Epoch [76/100] - Train Loss: 0.0056, Test Loss: 1.5948, Accuracy: 90.83%
# Epoch [77/100] - Train Loss: 0.1132, Test Loss: 1.6585, Accuracy: 87.79%
# Epoch [78/100] - Train Loss: 0.1062, Test Loss: 1.4279, Accuracy: 88.93%
# Epoch [79/100] - Train Loss: 0.0545, Test Loss: 1.7887, Accuracy: 90.29%
# Epoch [80/100] - Train Loss: 0.0815, Test Loss: 1.6603, Accuracy: 89.45%
# Epoch [81/100] - Train Loss: 0.0737, Test Loss: 1.6118, Accuracy: 90.57%
# Epoch [82/100] - Train Loss: 0.0197, Test Loss: 1.5256, Accuracy: 91.19%
# Epoch [83/100] - Train Loss: 0.0173, Test Loss: 1.7761, Accuracy: 89.95%
# Epoch [84/100] - Train Loss: 0.0357, Test Loss: 2.0576, Accuracy: 90.74%
# Epoch [85/100] - Train Loss: 0.1575, Test Loss: 2.8940, Accuracy: 87.52%
# Epoch [86/100] - Train Loss: 0.1852, Test Loss: 1.6819, Accuracy: 87.53%
# Epoch [87/100] - Train Loss: 0.3608, Test Loss: 1.5011, Accuracy: 84.33%
# Epoch [88/100] - Train Loss: 0.2750, Test Loss: 1.8858, Accuracy: 86.27%
# Epoch [89/100] - Train Loss: 0.1785, Test Loss: 1.7156, Accuracy: 87.66%
# Epoch [90/100] - Train Loss: 0.1573, Test Loss: 1.7928, Accuracy: 85.13%
# Epoch [91/100] - Train Loss: 0.0685, Test Loss: 1.8825, Accuracy: 89.09%
# Epoch [92/100] - Train Loss: 0.1983, Test Loss: 1.7457, Accuracy: 83.15%
# Epoch [93/100] - Train Loss: 0.1924, Test Loss: 1.9989, Accuracy: 88.17%
# Epoch [94/100] - Train Loss: 0.0988, Test Loss: 3.0345, Accuracy: 88.53%
# Epoch [95/100] - Train Loss: 0.0618, Test Loss: 2.2273, Accuracy: 88.24%
# Epoch [96/100] - Train Loss: 0.0569, Test Loss: 2.4219, Accuracy: 89.37%
# Epoch [97/100] - Train Loss: 0.2987, Test Loss: 1.5995, Accuracy: 82.27%
# Epoch [98/100] - Train Loss: 0.1432, Test Loss: 2.4401, Accuracy: 87.24%
# Epoch [99/100] - Train Loss: 0.0999, Test Loss: 1.6540, Accuracy: 88.00%
# Epoch [100/100] - Train Loss: 0.3878, Test Loss: 2.0890, Accuracy: 88.50%

# %%
# 데이터 변환에 데이터 증강 기법 추가
transform_augmented = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.ToImage(),
    transforms.ToDtype(torch.float32, scale=True)
])

# 데이터셋 및 로더 재정의
train_dataset_augmented = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform_augmented)
train_subset_augmented = torch.utils.data.Subset(train_dataset_augmented, subset_indices)
train_loader_augmented = torch.utils.data.DataLoader(train_subset_augmented, batch_size=64, shuffle=True)
# Out:
# c:\sk-encoa\dl-workspace\.venv\Lib\site-packages\torchvision\transforms\v2\_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(
